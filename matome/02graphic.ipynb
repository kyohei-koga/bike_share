# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import seaborn as sns
# %matplotlib inline

# %%
status = pd.read_csv('/home/kyohei/bike_share/data_split_2015/San Francisco_station_status_stid69.csv')

# %%
station = pd.read_csv('/home/kyohei/bike_share_data/201608_station_data.csv')

# %%
#datetime変換
status.time = status.time.apply(lambda x:pd.to_datetime(x))

# %%
#曜日
status['dayofweek'] = status.time.apply(lambda x:x.dayofweek)

#日付
status['date'] = status.time.apply(lambda x:x.date())

#時間
status['hour_minute'] = status.time.apply(lambda x:datetime.time(x.hour,x.minute))

#available bikes rate
status['op_rate_bikes'] = status.bikes_available / float(station[station.station_id==69]['dockcount'].values)

#available docks rate
status['op_rate_docks'] = status.docks_available / float(station[station.station_id==69]['dockcount'].values)

# %%
#平日データに限定
status_sub = status[status.dayofweek<=4]

# %%
#平均的な振る舞い
status_sub.groupby('hour_minute')['op_rate_bikes'].mean().plot(figsize=(10,5))
plt.ylim([0,1])
plt.ylabel('Average rate of available bikes')
plt.xticks(time_range)
# Out:
# ([<matplotlib.axis.XTick at 0x7f1abe051f10>,
#   <matplotlib.axis.XTick at 0x7f1abadb00d0>,
#   <matplotlib.axis.XTick at 0x7f1abac83c10>,
#   <matplotlib.axis.XTick at 0x7f1abac90790>,
#   <matplotlib.axis.XTick at 0x7f1abac90f10>,
#   <matplotlib.axis.XTick at 0x7f1abaca36d0>,
#   <matplotlib.axis.XTick at 0x7f1abaca3e50>],
#  <a list of 7 Text xticklabel objects>)

# %%
time_range = []

for i in range(6):
    time_range.append(datetime.time(i*4,0,0))

time_range.append(datetime.time(23,59))

# %%
time_range
# Out:
# [datetime.time(0, 0),
#  datetime.time(4, 0),
#  datetime.time(8, 0),
#  datetime.time(12, 0),
#  datetime.time(16, 0),
#  datetime.time(20, 0)]

# %%
status_zero = status_sub[status_sub.hour_minute==datetime.time(0,0)]

status_high_bikes_date = status_zero[status_zero.bikes_available>=20]['date']

status_high_sub = status_sub[status_sub.date.isin(status_high_bikes_date)]

status_high_sub.head()
# Out:
#       Unnamed: 0  station_id  bikes_available  docks_available  \
# 2880    28903375          69               20                3
# 2881    28903376          69               20                3
# 2882    28903377          69               20                3
# 2883    28903378          69               20                3
# 2884    28903379          69               20                3
#
#                     time  dayofweek        date hour_minute  op_rate_bikes  \
# 2880 2015-09-03 00:00:02          3  2015-09-03    00:00:00       0.869565
# 2881 2015-09-03 00:01:02          3  2015-09-03    00:01:00       0.869565
# 2882 2015-09-03 00:02:03          3  2015-09-03    00:02:00       0.869565
# 2883 2015-09-03 00:03:02          3  2015-09-03    00:03:00       0.869565
# 2884 2015-09-03 00:04:02          3  2015-09-03    00:04:00       0.869565
#
#       op_rate_docks
# 2880       0.130435
# 2881       0.130435
# 2882       0.130435
# 2883       0.130435
# 2884       0.130435

# %%
#0時に空きバイクの量が多い時の振る舞い
ax = plt.axes()
status_high_sub.groupby('hour_minute')['op_rate_bikes'].mean().plot(ax=ax,figsize=(10,5))
status_high_sub.groupby('hour_minute')['op_rate_docks'].mean().plot(ax=ax)
plt.ylim([0,1])
# Out:
# (0, 1)

# %%
status_16 = status_sub[status_sub.hour_minute==datetime.time(16,0)]

status_high_docks_date = status_16[status_16.docks_available>=20]['date']

status_high_sub = status_sub[status_sub.date.isin(status_high_docks_date)]

status_high_sub.head()
# Out:
#        Unnamed: 0  station_id  bikes_available  docks_available  \
# 18720    28919215          69               11               12
# 18721    28919216          69               11               12
# 18722    28919217          69               11               12
# 18723    28919218          69               11               12
# 18724    28919219          69               11               12
#
#                      time  dayofweek        date hour_minute  op_rate_bikes  \
# 18720 2015-09-14 00:00:02          0  2015-09-14    00:00:00       0.478261
# 18721 2015-09-14 00:01:03          0  2015-09-14    00:01:00       0.478261
# 18722 2015-09-14 00:02:02          0  2015-09-14    00:02:00       0.478261
# 18723 2015-09-14 00:03:02          0  2015-09-14    00:03:00       0.478261
# 18724 2015-09-14 00:04:02          0  2015-09-14    00:04:00       0.478261
#
#        op_rate_docks
# 18720       0.521739
# 18721       0.521739
# 18722       0.521739
# 18723       0.521739
# 18724       0.521739

# %%
#16時に空きドックの量が多い時の振る舞い
ax = plt.axes()
status_high_sub.groupby('hour_minute')['op_rate_bikes'].mean().plot(ax=ax,figsize=(10,5))
status_high_sub.groupby('hour_minute')['op_rate_docks'].mean().plot(ax=ax)
plt.ylim([0,1])
# Out:
# (0, 1)
