# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
trip = pd.read_csv('/home/kyohei/bike_share_data/201608_trip_data.csv')

# %%
station = pd.read_csv('/home/kyohei/bike_share_data/201608_station_data.csv')

# %%
#サンフランシスコ発のデータに限定
station_sub = station[['station_id','landmark']]

station_sub_sf = station_sub[station_sub['landmark']=='San Francisco']

trip_merge_landmark = trip.merge(station_sub_sf,left_on='Start Terminal',right_on='station_id',how='inner')

# %%
#日付データの変換
trip_merge_landmark['Start Date'] = trip_merge_landmark['Start Date'].apply(lambda x:pd.to_datetime(x))

#曜日データの付与
trip_merge_landmark['dayofweek'] = trip_merge_landmark['Start Date'].apply(lambda x:x.dayofweek)

#日付データの付与
trip_merge_landmark['start_date'] = trip_merge_landmark['Start Date'].apply(lambda x:x.date())

# %%
#曜日別の一日平均利用回数（スタートベース、San Francisco地区）
trip_merge_landmark_groupby_date = pd.DataFrame(trip_merge_landmark.groupby(['start_date','dayofweek']).size()).reset_index()

trip_merge_landmark_groupby_date.groupby('dayofweek')[0].mean().plot(kind='bar')

# %%
#時間データの付加
trip_merge_landmark['hour'] = trip_merge_landmark['Start Date'].apply(lambda x:x.time().hour)

# %%
#曜日別の平均貸出数推移の作成
#日付別、曜日別、時間別貸出数の算出
trip_merge_landmark_group_date_hour = pd.DataFrame(trip_merge_landmark.groupby(['start_date','dayofweek','hour']).size()).reset_index()

#曜日別、時間別、平均貸出数の算出
plot_data = pd.DataFrame(trip_merge_landmark_group_date_hour.groupby(['dayofweek','hour'])[0].mean()).reset_index()

# %%
fig, axes = plt.subplots(3,3,figsize=(15,10))
dayofweeks = [0,1,2,3,4,5,6]
targets = zip(dayofweeks,axes.flatten())

for (dayofweek,ax) in targets:
    plot_data[plot_data['dayofweek']==dayofweek].plot('hour',0,ax=ax,style='-o')

# %%
#平日データに限定
trip_merge_landmark_weekday = trip_merge_landmark[trip_merge_landmark.dayofweek<=4]

# %%
#利用数top
start_station_ranking = trip_merge_landmark_weekday.groupby(['Start Terminal','Start Station']).size().sort_values(ascending=False)
start_station_ranking
# Out:
# Start Terminal  Start Station
# 70              San Francisco Caltrain (Townsend at 4th)         22662
# 69              San Francisco Caltrain 2 (330 Townsend)          21593
# 50              Harry Bridges Plaza (Ferry Building)             14090
# 61              2nd at Townsend                                  12876
# 74              Steuart at Market                                12795
# 55              Temporary Transbay Terminal (Howard at Beale)    12680
# 60              Embarcadero at Sansome                           11251
# 65              Townsend at 7th                                  10527
# 77              Market at Sansome                                10316
# 67              Market at 10th                                    9108
# 64              2nd at South Park                                 7278
# 63              Howard at 2nd                                     7236
# 51              Embarcadero at Folsom                             7160
# 62              2nd at Folsom                                     7086
# 56              Beale at Market                                   6859
# 54              Embarcadero at Bryant                             6447
# 76              Market at 4th                                     6287
# 39              Powell Street BART                                5854
# 73              Grant Avenue at Columbus Avenue                   5744
# 82              Broadway St at Battery St                         5325
# 75              Mechanics Plaza (Market at Battery)               5261
# 57              5th at Howard                                     4936
# 66              South Van Ness at Market                          4837
# 45              Commercial at Montgomery                          4760
# 49              Spear at Folsom                                   4688
# 42              Davis at Jackson                                  4574
# 72              Civic Center BART (7th at Market)                 4441
# 48              Embarcadero at Vallejo                            4117
# 41              Clay at Battery                                   3938
# 47              Post at Kearny                                    3909
# 71              Powell at Post (Union Square)                     3725
# 68              Yerba Buena Center of the Arts (3rd @ Howard)     2963
# 59              Golden Gate at Polk                               2957
# 46              Washington at Kearny                              2232
# 58              San Francisco City Hall                           1836
# 90              5th St at Folsom St                                145
# 91              Cyril Magnin St at Ellis St                         53
# dtype: int64

# %%
start_station_ranking.mean()
# Out:
# 7095.8378378378375

# %%
#返却数top
end_station_ranking = trip_merge_landmark_weekday.groupby(['End Terminal','End Station']).size().sort_values(ascending=False)
end_station_ranking
# Out:
# End Terminal  End Station
# 70            San Francisco Caltrain (Townsend at 4th)         27831
# 69            San Francisco Caltrain 2 (330 Townsend)          22819
# 50            Harry Bridges Plaza (Ferry Building)             14916
# 61            2nd at Townsend                                  14411
# 74            Steuart at Market                                13531
# 60            Embarcadero at Sansome                           12674
# 77            Market at Sansome                                12243
# 55            Temporary Transbay Terminal (Howard at Beale)    11961
# 65            Townsend at 7th                                  11213
# 63            Howard at 2nd                                     7256
# 67            Market at 10th                                    7240
# 51            Embarcadero at Folsom                             7190
# 64            2nd at South Park                                 6695
# 39            Powell Street BART                                5960
# 57            5th at Howard                                     5827
# 76            Market at 4th                                     5749
# 56            Beale at Market                                   5436
# 75            Mechanics Plaza (Market at Battery)               5364
# 54            Embarcadero at Bryant                             5196
# 42            Davis at Jackson                                  5192
# 45            Commercial at Montgomery                          4919
# 49            Spear at Folsom                                   4745
# 48            Embarcadero at Vallejo                            4508
# 82            Broadway St at Battery St                         4380
# 72            Civic Center BART (7th at Market)                 4132
# 66            South Van Ness at Market                          4049
# 62            2nd at Folsom                                     4044
# 41            Clay at Battery                                   3870
# 47            Post at Kearny                                    3836
# 68            Yerba Buena Center of the Arts (3rd @ Howard)     3450
# 73            Grant Avenue at Columbus Avenue                   2773
# 46            Washington at Kearny                              2607
# 71            Powell at Post (Union Square)                     2502
# 59            Golden Gate at Polk                               2317
# 58            San Francisco City Hall                           1515
# 90            5th St at Folsom St                                134
# 91            Cyril Magnin St at Ellis St                         55
# 22            Redwood City Caltrain Station                        4
# 3             San Jose Civic Center                                1
# 2             San Jose Diridon Caltrain Station                    1
# dtype: int64

# %%
end_station_ranking.mean()
# Out:
# 6563.65
